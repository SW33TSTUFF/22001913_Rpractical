# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/home/simaak/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) + 
    geom_point() +
    labs(title = "Car Weight vs MPG",
         x = "Weight",
         y = "Miles Per Gallon")
# Out:
# plot without title
